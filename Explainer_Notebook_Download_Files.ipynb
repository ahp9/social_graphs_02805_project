# %%
import os
import time
import json
import urllib.parse
import urllib.request

# %%
baseurl = "https://en.wikipedia.org/w/api.php"
user_agent = "PremierLeagueManagerDownloader/2.0"

# %%
def get_category_members(category_title, depth=1, exclude_subcats=None):
    """
    Fetch all page titles in a Wikipedia category.
    Automatically skips unwanted subcategories in exclude_subcats.
    """
    if exclude_subcats is None:
        exclude_subcats = []

    members = []
    cmcontinue = ""

    while True:
        params = {
            "action": "query",
            "list": "categorymembers",
            "cmtitle": f"Category:{category_title}",
            "cmlimit": "max",
            "format": "json"
        }
        if cmcontinue:
            params["cmcontinue"] = cmcontinue

        query = baseurl + "?" + urllib.parse.urlencode(params)
        req = urllib.request.Request(query, headers={"User-Agent": user_agent})
        with urllib.request.urlopen(req) as response:
            data = json.loads(response.read().decode("utf-8"))

        pages = data.get("query", {}).get("categorymembers", [])
        
        for p in pages:
            ns = p["ns"]
            title = p["title"]

            # Skip unwanted subcategories
            if ns == 14:  # category namespace
                clean = title.replace("Category:", "")
                if clean in exclude_subcats:
                    print(f" kipping excluded subcategory: {title}")
                    continue

                if depth > 0:
                    print(f"Exploring subcategory: {title}")
                    members += get_category_members(clean, depth - 1, exclude_subcats)
                continue

            # Add the page
            if ns == 0:  
                members.append(title)

        if "continue" in data:
            cmcontinue = data["continue"]["cmcontinue"]
            time.sleep(0.3)
        else:
            break

    return members


# Fetch the wikitext of a Wikipedia page given its title
def fetch_wikitext(title):
    params = {
        "action": "query",
        "prop": "revisions",
        "rvslots": "main",
        "rvprop": "content",
        "titles": title,
        "format": "json",
    }
    query = baseurl + "?" + urllib.parse.urlencode(params)
    req = urllib.request.Request(query, headers={"User-Agent": user_agent})

    with urllib.request.urlopen(req) as response:
        data = json.loads(response.read().decode("utf-8"))

    page = next(iter(data["query"]["pages"].values()))
    try:
        return page["revisions"][0]["slots"]["main"]["*"]
    except Exception:
        return None


# Save a page's wikitext to a file
def save_page(title, folder):
    text = fetch_wikitext(title)
    if not text:
        print(f"No text found for {title}. Skipping.")
        return

    safe = title.replace("/", "_").replace(":", "_")
    path = os.path.join(folder, safe + ".txt")

    with open(path, "w", encoding="utf-8") as f:
        f.write(text)

    print(f"Saved: {title}")

# %%
save_dir = "managers_test"
os.makedirs(save_dir, exist_ok=True)

EXCLUDE = ["Lists of Premier League managers"]

print("Fetching Premier League Managers...")
managers = get_category_members(
    "Premier League managers",
    depth=1,
    exclude_subcats=EXCLUDE
)

print(f"Found {len(managers)} manager pages")

for m in managers:
    save_page(m, save_dir)
    time.sleep(0.5)
# Out:
# Fetching Premier League Managers...
#  kipping excluded subcategory: Category:Lists of Premier League managers
# Found 287 manager pages
# Saved: Micky Adams
# Saved: Neil Adams (footballer)
# Saved: Tony Adams
# Saved: Nigel Adkins
# Saved: Dick Advocaat
# Saved: Steve Agnew
# Saved: Sam Allardyce
# Saved: Clive Allen
# Saved: Ruben Amorim
# Saved: Carlo Ancelotti
# Saved: Keith Andrews (footballer)
# Saved: Michael Appleton
# Saved: Osvaldo Ardiles
# Saved: Mikel Arteta
# Saved: Ron Atkinson
# Saved: Alan Ball Jr.
# Saved: Kevin Ball
# Saved: Frank Barlow (footballer)
# Saved: Dave Bassett
# Saved: Rafael Benítez
# Saved: Marcelo Bielsa
# Saved: Slaven Bilić
# Saved: Eric Black
# Saved: Frank de Boer
# Saved: Billy Bonds
# Saved: Tony Book
# Saved: Aidy Boothroyd
# Saved: Mark Bowen (footballer)
# Saved: Bob Bradley
# Saved: Ian Branfoot
# Saved: Leon Britton
# Saved: Trevor Brooking
# Saved: Phil Brown (footballer, born 1959)
# Saved: Steve Bruce
# Saved: George Burley
# Saved: Frank Burrows
# Saved: Terry Burton
# Saved: Michael Carrick
# Saved: Carlos Carvalhal
# Saved: John Carver (footballer)
# Saved: Frank Clark (footballer)
# Saved: Steve Clarke
# Saved: Ray Clemence
# Saved: Paul Clement (football manager)
# Saved: Brian Clough
# Saved: Chris Coleman (footballer)
# Saved: Terry Connor
# Saved: Antonio Conte
# Saved: Steve Cooper (football manager)
# Saved: Steve Coppell
# Saved: Owen Coyle
# Saved: Alan Curbishley
# Saved: Alan Curtis (footballer)
# Saved: Kenny Dalglish
# Saved: Aaron Danks
# Saved: Billy Davies
# Saved: Kelvin Davis (footballer)
# Saved: Steve Davis (footballer, born 1965)
# Saved: Ben Dawson
# Saved: Roberto De Zerbi
# Saved: John Deehan
# Saved: Paolo Di Canio
# Saved: Roberto Di Matteo
# Saved: Eamonn Dolan
# Saved: Iain Dowie
# Saved: Keith Downing
# Saved: Sean Dyche
# Saved: Rob Edwards (footballer, born 1982)
# Saved: Unai Emery
# Saved: Sven-Göran Eriksson
# Saved: Nuno Espírito Santo
# Saved: Roy Evans
# Saved: Daniel Farke
# Saved: Alex Ferguson
# Saved: Duncan Ferguson
# Saved: Gerry Francis
# Saved: Trevor Francis
# Saved: Thomas Frank (football manager)
# Saved: Louis van Gaal
# Saved: Jimmy Gabriel
# Saved: Rémi Garde
# Saved: Steven Gerrard
# Saved: Ryan Giggs
# Saved: Oliver Glasner
# Saved: Paul Goddard (footballer)
# Saved: John Gorman (footballer)
# Saved: Bobby Gould
# Saved: Javi Gracia
# Saved: George Graham
# Saved: Avram Grant
# Saved: Eddie Gray (footballer, born 1948)
# Saved: Stuart Gray (footballer, born 1960)
# Saved: John Gregory (footballer)
# Saved: Christian Gross
# Saved: Pep Guardiola
# Saved: Francesco Guidolin
# Saved: Ruud Gullit
# Saved: Erik ten Hag
# Saved: Ray Harford
# Saved: Paul Hart
# Saved: Ralph Hasenhüttl
# Saved: Paul Heckingbottom
# Saved: Guus Hiddink
# Saved: Glenn Hoddle
# Saved: Roy Hodgson
# Saved: Steve Holland (footballer)
# Saved: Ian Holloway
# Saved: Brian Horton
# Saved: Gérard Houllier
# Saved: Stewart Houston
# Saved: Eddie Howe
# Saved: Mark Hughes
# Saved: Chris Hughton
# Saved: Fabian Hürzeler
# Saved: Chris Hutchings
# Saved: Paul Ince
# Saved: Andoni Iraola
# Saved: Alan Irvine (footballer, born 1958)
# Saved: Mike Jackson (footballer, born 1973)
# Saved: Jim Jefferies (footballer)
# Saved: Paul Jewell
# Saved: Slaviša Jokanović
# Saved: Martin Jol
# Saved: Dave Jones (footballer, born 1956)
# Saved: Graeme Jones
# Saved: Nathan Jones (Welsh footballer)
# Saved: Joe Jordan
# Saved: Ivan Jurić
# Saved: Aitor Karanka
# Saved: Steve Kean
# Saved: Roy Keane
# Saved: Kevin Keegan
# Saved: Kevin Keen
# Saved: Rob Kelly
# Saved: Howard Kendall
# Saved: David Kerslake
# Saved: Brian Kidd
# Saved: Joe Kinnear
# Saved: Jürgen Klopp
# Saved: Archie Knox
# Saved: Ronald Koeman
# Saved: Vincent Kompany
# Saved: Bruno Lage
# Saved: Paul Lambert
# Saved: Frank Lampard
# Saved: Michael Laudrup
# Saved: Lennie Lawrence
# Saved: Brian Laws
# Saved: Régis Le Bris
# Saved: Sammy Lee (footballer)
# Saved: Ray Lewington
# Saved: List of Premier League managers
# Saved: Brian Little
# Saved: Doug Livermore
# Saved: Freddie Ljungberg
# Saved: Attilio Lombardo
# Saved: Julen Lopetegui
# Saved: John Lyall
# Saved: Kevin MacDonald (footballer)
# Saved: Malky Mackay
# Saved: Felix Magath
# Saved: Roberto Mancini
# Saved: Enzo Maresca
# Saved: Jesse Marsch
# Saved: Andy Marshall
# Saved: Scott Marshall (footballer)
# Saved: Russell Martin (footballer)
# Saved: Roberto Martínez
# Saved: Ryan Mason
# Saved: Walter Mazzarri
# Saved: Gary McAllister
# Saved: Stuart McCall
# Saved: Mick McCarthy
# Saved: Paddy McCarthy
# Saved: Steve McClaren
# Saved: Brian McDermott (footballer)
# Saved: Terry McDermott
# Saved: Billy McEwan (footballer, born 1951)
# Saved: Roy McFarland
# Saved: Mark McGhee
# Saved: Alex McLeish
# Saved: Gary Megson
# Saved: Pepe Mel
# Saved: Dave Merrington
# Saved: René Meulensteen
# Saved: Keith Millen
# Saved: Garry Monk
# Saved: Darren Moore
# Saved: José Mourinho
# Saved: Tony Mowbray
# Saved: David Moyes
# Saved: Hayden Mullins
# Saved: Phil Neal
# Saved: Alex Neil (footballer)
# Saved: Ruud van Nistelrooy
# Saved: Ron Noades
# Saved: David O'Leary
# Saved: Egil Olsen
# Saved: Gary O'Neil
# Saved: Martin O'Neill
# Saved: Alan Pardew
# Saved: Scott Parker
# Saved: Tony Parkes
# Saved: Stuart Pearce
# Saved: Nigel Pearson
# Saved: Manuel Pellegrini
# Saved: Mauricio Pellegrino
# Saved: Vítor Pereira (footballer, born 1968)
# Saved: Alain Perrin
# Saved: Steve Perryman
# Saved: Mike Phelan
# Saved: David Pleat
# Saved: Mauricio Pochettino
# Saved: Ian Porterfield
# Saved: Ange Postecoglou
# Saved: Graham Potter
# Saved: Gus Poyet
# Saved: Claude Puel
# Saved: Tony Pulis
# Saved: Juande Ramos
# Saved: Chris Ramsey (footballer)
# Saved: Ralf Rangnick
# Saved: Claudio Ranieri
# Saved: Harry Redknapp
# Saved: Les Reed (football manager)
# Saved: Peter Reid
# Saved: Pat Rice
# Saved: Bruce Rioch
# Saved: Graham Rix
# Saved: Bobby Robson
# Saved: Bryan Robson
# Saved: Brendan Rodgers
# Saved: Glenn Roeder
# Saved: Joe Royle
# Saved: Simon Rusk
# Saved: Adam Sadler
# Saved: Quique Sánchez Flores
# Saved: Lawrie Sanchez
# Saved: Jacques Santini
# Saved: Maurizio Sarri
# Saved: Ricky Sbragia
# Saved: Luiz Felipe Scolari
# Saved: Rubén Sellés
# Saved: Craig Shakespeare
# Saved: Alan Shearer
# Saved: Tim Sherwood
# Saved: Peter Shreeves
# Saved: Jan Siewert
# Saved: Marco Silva
# Saved: Michael Skubala
# Saved: Arne Slot
# Saved: Alan Smith (football manager)
# Saved: Dean Smith (footballer, born 1971)
# Saved: Jim Smith (footballer, born 1940)
# Saved: Walter Smith
# Saved: Ole Gunnar Solskjær
# Saved: Graeme Souness
# Saved: Gareth Southgate
# Saved: Cristian Stellini
# Saved: Mike Stowell
# Saved: Gordon Strachan
# Saved: Paul Sturrock
# Saved: Graham Taylor
# Saved: Peter Taylor (footballer, born 1953)
# Saved: Phil Thompson
# Saved: Jean Tigana
# Saved: Colin Todd
# Saved: Thomas Tuchel
# Saved: David Unsworth
# Saved: Terry Venables
# Saved: Gianluca Vialli
# Saved: André Villas-Boas
# Saved: David Wagner (soccer)
# Saved: Mike Walker (Welsh footballer)
# Saved: Neil Warnock
# Saved: Dave Watson
# Saved: David Webb (footballer)
# Saved: Arsène Wenger
# Saved: Steve Wigley
# Saved: Chris Wilder
# Saved: Ray Wilkins
# Saved: Howard Wilkinson
# Saved: Danny Wilson (footballer, born 1960)
# Saved: Nigel Worthington
# Saved: Xisco Muñoz
# Saved: Velimir Zajec
# Saved: Gianfranco Zola

# %%
football_pages = [
    "Glossary of association football terms",
    "Association football tactics and skills",
    "Formation (association football)",
    "Association football positions",
    "Association football",
]

football_save_dir = "football_pages_test"
os.makedirs(football_save_dir, exist_ok=True)

print("\nFetching Football Topic Pages...")

for title in football_pages:
    save_page(title, football_save_dir)
    time.sleep(0.4)
# Out:
# Fetching Football Topic Pages...
# Saved: Glossary of association football terms
# Saved: Association football tactics and skills
# Saved: Formation (association football)
# Saved: Association football positions
# Saved: Association football

# %%
terminology_save_dir = "football_terminology_test"
os.makedirs(terminology_save_dir, exist_ok=True)

category_title = "Association football terminology"

print(f"\nFetching category: {category_title}")

terminology_pages = get_category_members(
    category_title,
    depth=1,                   
)

print(f"Found {len(terminology_pages)} pages in category '{category_title}'.")

for title in terminology_pages:
    save_page(title, terminology_save_dir)
    time.sleep(0.3)
# Out:
# Fetching category: Association football terminology
# Exploring subcategory: Category:Hat-trick (association football)
# Exploring subcategory: Category:Nicknamed groups of association football players
# Found 253 pages in category 'Association football terminology'.
# Saved: Association football
# Saved: Glossary of association football terms
# Saved: Association football tactics and skills
# Saved: 2–0 lead is the worst lead
# Saved: 4th place trophy
# Saved: 6+5 rule
# Saved: 12th man (football)
# Saved: Administration (British football)
# Saved: All-seater stadium
# Saved: Angeball
# Saved: Anti-football
# Saved: Apertura and Clausura
# Saved: Article 52 of NOIF
# Saved: Assist (association football)
# Saved: Assistant referee (association football)
# Saved: Away goals rule
# Saved: Back-pass rule
# Saved: Ball boy
# Saved: Ball in and out of play
# Saved: Ballet Azul
# Saved: The beautiful game
# Saved: Best and fairest
# Saved: Bicycle kick
# Saved: Big Five (Argentine football)
# Saved: Big Four (Mexico)
# Saved: Big Six (Premier League)
# Saved: Boot boy
# Saved: Bosman ruling
# Saved: Buyout clause
# Saved: Caceres rule
# Saved: Cap (sport)
# Saved: Cap-tied
# Saved: Captain (association football)
# Saved: Caretaker manager
# Saved: Catenaccio
# Saved: Channel (association football)
# Saved: Chip (association football)
# Saved: Clasico
# Saved: Closed league
# Saved: Association football club names
# Saved: Co-ownership (association football)
# Saved: Association football contracts
# Saved: Corner kick
# Saved: Corridor of uncertainty
# Saved: Cross (association football)
# Saved: Cruyff turn
# Saved: Cup-tied
# Saved: Curl (association football)
# Saved: Curva
# Saved: Dead rubber
# Saved: Defender (association football)
# Saved: Designated Player Rule
# Saved: Diamond formation
# Saved: Diving (association football)
# Saved: Domestic association football season
# Saved: Domestic cup
# Saved: Double (association football)
# Saved: Dribbling
# Saved: Dubious Goals Committee
# Saved: Dummy (football)
# Saved: El Dorado (Colombian football)
# Saved: Empty net goal
# Saved: Equaliser (sports)
# Saved: EU status (football)
# Saved: Expected goals
# Saved: False 9
# Saved: Fanwalk
# Saved: FIFA eligibility rules
# Saved: First XI
# Saved: Fit-and-proper-person test
# Saved: Flip flap (association football)
# Saved: Flo pass
# Saved: Football (ball)
# Saved: Football association
# Saved: Football club (association football)
# Saved: Formation (association football)
# Saved: Forward (association football)
# Saved: Fouls and misconduct (association football)
# Saved: Free kick (association football)
# Saved: Free transfer (association football)
# Saved: Freestyle football
# Saved: Futsal
# Saved: G-12 (Brazilian football)
# Saved: Ghost goal
# Saved: Goal (sports)
# Saved: Goal average
# Saved: Goal celebration
# Saved: Goal difference
# Saved: Goalkeeper (association football)
# Saved: Grandfather rule
# Saved: Group of death
# Saved: Guard of honour
# Saved: Hat-trick
# Saved: Header (association football)
# Saved: High press
# Saved: High tackle
# Saved: Interception
# Saved: Jockeying (association football)
# Saved: De kabel
# Saved: Keepie uppie
# Saved: Kick (association football)
# Saved: Last-minute goal
# Saved: Laws of the Game (association football)
# Saved: League cup
# Saved: Loan (sports)
# Saved: Local derby
# Saved: Long ball
# Saved: Major trophy
# Saved: Manager (association football)
# Saved: Marking (association football)
# Saved: Marquee player (A-League Men)
# Saved: Marseille turn
# Saved: Matricule
# Saved: Mickey Mouse cup
# Saved: Midfielder
# Saved: MLS International Roster Slots
# Saved: Multiball system
# Saved: Nachalnik Komandy
# Saved: New Maradona
# Saved: Nutmeg (association football)
# Saved: Off the ball
# Saved: Offside (association football)
# Saved: Old Firm
# Saved: Olimpico goal
# Saved: Olympic goal
# Saved: Omegaball
# Saved: One on one tackle
# Saved: One-touch football
# Saved: Original Glasgow derby
# Saved: Own goal
# Saved: Panenka (penalty kick)
# Saved: Passing (association football)
# Saved: Runaround move
# Saved: Penalty area
# Saved: Penalty card
# Saved: Penalty kick (association football)
# Saved: Penalty shoot-out (association football)
# Saved: Perfect season
# Saved: Phoenix club (sports)
# Saved: Pitch invasion
# Saved: Player escort
# Saved: Player of the match
# Saved: Playmaker
# Saved: Prawn sandwich brigade
# Saved: Pride of Anglia
# Saved: Professional foul
# Saved: Matchday programme
# Saved: Promotion and relegation
# Saved: Push and run
# Saved: Rabona
# Saved: Rainbow kick
# Saved: Rebound (sports)
# Saved: Reserve team
# Saved: List of retired numbers in association football
# Saved: Revie Plan
# Saved: Safe standing
# Saved: Save (goaltender)
# Saved: Scoring in association football
# Saved: Scorpion kick (association football)
# Saved: Seal dribble
# Saved: Semi-closed league
# Saved: Set piece (football)
# Saved: Sevens football
# Saved: Sextuple (association football)
# Saved: Shooting (association football)
# Saved: Sidelines
# Saved: Six-pointer
# Saved: Sliding tackle
# Saved: Soccer-specific stadium
# Saved: Spear tackle
# Saved: Spion Kop (stadiums)
# Saved: Sporting director
# Saved: Squad number (association football)
# Saved: Stanchion
# Saved: Step over
# Saved: Striking partnership
# Saved: Substitute (association football)
# Saved: Super cup
# Saved: Tackle (football move)
# Saved: Tapping up
# Saved: Target forward
# Saved: Technical area
# Saved: Test match (association football)
# Saved: Testimonial match
# Saved: Third-party ownership in association football
# Saved: Throw-in
# Saved: Tie (draw)
# Saved: Tiki-taka
# Saved: Timewasting
# Saved: Toe punt
# Saved: Total Football
# Saved: Touch-line
# Saved: Training ground (association football)
# Saved: Transfer (association football)
# Saved: Transfer ban (association football)
# Saved: Transfer window
# Saved: Treble (association football)
# Saved: Two-legged tie
# Saved: Under-soil heating
# Saved: Victory International
# Saved: Volley (association football)
# Saved: Webster ruling
# Saved: Winger (association football)
# Saved: Work rate
# Saved: Works team
# Saved: World Freestyle Football Association
# Saved: Yo-yo club
# Saved: Youth system
# Saved: Zona Cesarini
# Saved: Zona mista
# Saved: Blocco-Juve
# Saved: The Boys of 86
# Saved: Breslau Eleven
# Saved: Busby Babes
# Saved: Crazy Gang (football)
# Saved: Expresso da Vitória
# Saved: The Famous Five (football)
# Saved: Fergie's Fledglings
# Saved: The Front Five
# Saved: Galácticos
# Saved: Golden generation
# Saved: Golden Generation (English football)
# Saved: Golden Team
# Saved: Gre-No-Li
# Saved: The Invincibles (English football)
# Saved: Iron Curtain (football)
# Saved: De kabel
# Saved: Lisbon Lions
# Saved: La Máquina
# Saved: Metin-Ali-Feyyaz
# Saved: List of national association football teams by nickname
# Saved: List of AFC national association football teams by nickname
# Saved: List of CAF national association football teams by nickname
# Saved: List of CONCACAF national association football teams by nickname
# Saved: List of CONMEBOL national association football teams by nickname
# Saved: List of non-FIFA and former national association football teams by nickname
# Saved: List of OFC national association football teams by nickname
# Saved: List of UEFA national association football teams by nickname
# Saved: Nazio-Juve
# Saved: Os Magriços
# Saved: Os Santásticos
# Saved: Pancha Pandavas
# Saved: Quality Street Gang (Celtic F.C.)
# Saved: La Quinta del Buitre
# Saved: The Red Devils (national football team)
# Saved: Rodillo Negro
# Saved: Scotch Professors
# Saved: Spice Boys (footballers)
# Saved: Triple-Edged Sword
# Saved: United Trinity
# Saved: Wembley Wizards
# Saved: Wunderteam
# Saved: Yé-yé (Real Madrid)
